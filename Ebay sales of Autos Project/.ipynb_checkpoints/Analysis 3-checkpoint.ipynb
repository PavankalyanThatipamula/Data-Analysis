# %%
import pandas as pd
import numpy as np
import scipy.stats as ss
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Auto_Dataset.csv")

# %%
df.head(2)
# Out:
#            dateCrawled                            Name  Price Ab_test  \
# 0  2016-03-17 16:54:00              GOLF_4_1_4__3TÜRER   1500    test
# 1  2016-03-31 17:25:00  Skoda_Fabia_1.4_TDI_PD_Classic   3600    test
#
#   Vehicle_type  Registration_year  Gearbox  Power_PS  Model  Kilometer  \
# 0   kleinwagen               2001  manuell        75   golf     150000
# 1   kleinwagen               2008  manuell        69  fabia      90000
#
#    Registration_month fuel_type       brand Unrepaired_damage Date_created  \
# 0                   6    benzin  volkswagen              nein   2016-03-17
# 1                   7    diesel       skoda              nein   2016-03-31
#
#    Postal_code            Last_seen
# 0        91074  2016-03-17 17:40:00
# 1        60437  2016-06-04 10:17:00

# %% [raw]
# 1) The memory usage of the data is around 6.1 mb.How can we
# reduce the memory usage of the data set?
# 2) What is the Average price of vehicle by fuel type and gearbox
# type.Give a plot
# 3) What is the Average power of a vehicle by vehicle type and
# gearbox type.Give a plot
# 4) What is the Average price of a vehicle by brand as well as
# vehicle type.Use heatmap to explain this

# %% [markdown]
# ### The memory usage of the data is around 6.1 mb.How can we reduce the memory usage of the data set?

# %% [markdown]
# To optimize memory usage in Python, you can use memory-efficient data structures and algorithms, reduce the size of objects in memory, and minimize the use of global variables. You can also use profiling tools to identify areas of your code that use a lot of memory and optimize them.

# %%
df.memory_usage()
# Out:
# Index                      132
# dateCrawled            2087184
# name                   2087184
# seller                 2087184
# offerType              2087184
# price                  2087184
# abtest                 2087184
# vehicleType            2087184
# yearOfRegistration     2087184
# gearbox                2087184
# powerPS                2087184
# model                  2087184
# kilometer              2087184
# monthOfRegistration    2087184
# fuelType               2087184
# brand                  2087184
# notRepairedDamage      2087184
# dateCreated            2087184
# postalCode             2087184
# lastSeen               2087184
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248058 entries, 0 to 248057
# Data columns (total 17 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   dateCrawled         248058 non-null  object
#  1   Name                248058 non-null  object
#  2   Price               248058 non-null  int64
#  3   Ab_test             248058 non-null  object
#  4   Vehicle_type        248058 non-null  object
#  5   Registration_year   248058 non-null  int64
#  6   Gearbox             248058 non-null  object
#  7   Power_PS            248058 non-null  int64
#  8   Model               248058 non-null  object
#  9   Kilometer           248058 non-null  int64
#  10  Registration_month  248058 non-null  int64
#  11  fuel_type           248058 non-null  object
#  12  brand               248058 non-null  object
#  13  Unrepaired_damage   248058 non-null  object
#  14  Date_created        248058 non-null  object
# ...

# %% [markdown]
# ### What is the Average price of vehicle by fuel type and gearbox type.Give a plot

# %%
df.head(2)
# Out:
#            dateCrawled                            Name  Price Ab_test  \
# 0  2016-03-17 16:54:00              GOLF_4_1_4__3TÜRER   1500    test
# 1  2016-03-31 17:25:00  Skoda_Fabia_1.4_TDI_PD_Classic   3600    test
#
#   Vehicle_type  Registration_year  Gearbox  Power_PS  Model  Kilometer  \
# 0   kleinwagen               2001  manuell        75   golf     150000
# 1   kleinwagen               2008  manuell        69  fabia      90000
#
#    Registration_month fuel_type       brand Unrepaired_damage Date_created  \
# 0                   6    benzin  volkswagen              nein   2016-03-17
# 1                   7    diesel       skoda              nein   2016-03-31
#
#    Postal_code            Last_seen
# 0        91074  2016-03-17 17:40:00
# 1        60437  2016-06-04 10:17:00

# %%
pd.crosstab(df['fuel_type'],df['Gearbox'],df['Price'],aggfunc = 'mean')
# Out:
# Gearbox       automatik      manuell
# fuel_type
# andere      4149.090909  3497.023810
# benzin     10630.348056  5979.641581
# cng         7397.310345  4996.045000
# diesel     20792.929504  7449.163123
# elektro    10169.116279  4788.777778
# hybrid     15719.161850  6973.571429
# lpg         6023.237276  3584.640396

# %%
a =pd.crosstab(df['fuel_type'],df['Gearbox'],df['Price'],aggfunc = 'mean')
ax =a.plot(kind = 'bar')
ax.bar_label(ax.containers[0])
plt.ylabel('Average Price')
plt.xticks(rotation = 0)
plt.show()

# %%
Summary :
- Diesel fuel-type has high Average Price of 20792 for Automatic and 7449 for Manual gearbox
- Andere fuel-Type has low Average Price of 4149 for Automatic and 3497 for Manual gearbox
So, we conclude that Diesel fuel-type vehicle high Price for both Automatic and Manual gearbox compare to others . Andere  fuel-type vehicle has low Price in both Automatic and Manual gearbox

# %% [markdown]
# ### What is the Average power of a vehicle by vehicle type and gearbox type.Give a plot

# %%
df.head(2)
# Out:
#            dateCrawled                            Name  Price Ab_test  \
# 0  2016-03-17 16:54:00              GOLF_4_1_4__3TÜRER   1500    test
# 1  2016-03-31 17:25:00  Skoda_Fabia_1.4_TDI_PD_Classic   3600    test
#
#   Vehicle_type  Registration_year  Gearbox  Power_PS  Model  Kilometer  \
# 0   kleinwagen               2001  manuell        75   golf     150000
# 1   kleinwagen               2008  manuell        69  fabia      90000
#
#    Registration_month fuel_type       brand Unrepaired_damage Date_created  \
# 0                   6    benzin  volkswagen              nein   2016-03-17
# 1                   7    diesel       skoda              nein   2016-03-31
#
#    Postal_code            Last_seen
# 0        91074  2016-03-17 17:40:00
# 1        60437  2016-06-04 10:17:00

# %%
pd.crosstab(df['Vehicle_type'],df['Gearbox'],df['Power_PS'],aggfunc = 'mean')
# Out:
# Gearbox        automatik     manuell
# Vehicle_type
# andere        154.646259  102.193240
# bus           147.852542  114.727010
# cabrio        194.035812  139.909256
# coupe         227.001673  164.714644
# kleinwagen     79.528982   73.908784
# kombi         180.207643  129.687821
# limousine     188.611024  122.407209
# suv           214.732538  134.901235

# %%
a = pd.crosstab(df['Vehicle_type'],df['Gearbox'],df['Power_PS'],aggfunc = 'mean')
a.plot(kind ="bar")
plt.ylabel("Average_PowerPS")
plt.show()

# %%
sns.heatmap(pd.crosstab(df['Vehicle_type'],df['Gearbox'],df['Power_PS'],aggfunc = 'mean',normalize = 'columns'),annot = True)
# Out:
# <Axes: xlabel='Gearbox', ylabel='Vehicle_type'>

# %%
Summary :
- Coupe Vehicle-Type has high average Power of 227 for Automatic and 164 for Manual gearbox
- Suv Vehicle-Type has next high Average Power of 214  for Automatic  and 134 for Manual gearbox 
- Kleinwagen Vehicle-Type has low Average Power of 79 for Automatic and 73 for Manual gearbox
So, we conclude that Coupe and Suv vehicles have high Price for both Automatic and Manual gearbox compare to others . Kleinwagen vehicle has low Price in both Automatic and Manual gearbox

# %% [markdown]
# ### What is the Average price of a vehicle by brand as well as vehicle type.Use heatmap to explain this

# %%
pd.crosstab(df['Vehicle_type'],df['brand'],df['Price'],aggfunc = 'mean')
# Out:
# brand          alfa_romeo          audi           bmw     chevrolet  \
# Vehicle_type
# andere        1374.833333   7728.875000   3166.743056   9753.692308
# bus                   NaN   3331.250000  29552.978261   6557.529915
# cabrio        9786.437908  14211.468245  12927.985582  26263.269231
# coupe         7231.739796  17614.935043  10261.729076  17614.717391
# kleinwagen    5237.346369   8834.761905   5314.922449   3237.106987
# kombi         3951.517711  20168.428868   8363.798277   5274.703704
# limousine     3462.869986  20140.610575   8742.118712   6238.789474
# suv                   NaN  25263.236776  17131.249398  10135.741830
#
# brand            chrysler       citroen        dacia       daewoo  \
# Vehicle_type
# andere        7702.500000   4485.661017  5650.000000  1000.000000
# bus           3082.003356   4724.509286  8784.487179  1306.428571
# cabrio        4831.349112   4312.717949          NaN   900.000000
# ...

# %%
plt.figure(figsize = (10,5))
sns.heatmap(pd.crosstab(df['Vehicle_type'],df['brand'],df['Price'],aggfunc = 'mean'))
# Out:
# <Axes: xlabel='brand', ylabel='Vehicle_type'>

# %%
Summary :
- Coupe Vehicle-Type has high average Price of 39872 for Automatic and 11645 for Manual gearbox
- Suv Vehicle-Type has next high Average Price of 17405  for Automatic  and 10610 for Manual gearbox 
- Kleinwagen Vehicle-Type has low Average Price of 4266 for Automatic and 3008 for Manual gearbox
So, we conclude that Coupe and Suv vehicles have high Price for both Automatic and Manual gearbox compare to others . Kleinwagen vehicle has low Price in both Automatic and Manual gearbox
# Out:
#   Cell In[61], line 1
#     Summary :
#              ^
# SyntaxError: invalid syntax

# %%
df.head(2)
# Out:
#            dateCrawled                            Name  Price Ab_test  \
# 0  2016-03-17 16:54:00              GOLF_4_1_4__3TÜRER   1500    test
# 1  2016-03-31 17:25:00  Skoda_Fabia_1.4_TDI_PD_Classic   3600    test
#
#   Vehicle_type  Registration_year  Gearbox  Power_PS  Model  Kilometer  \
# 0   kleinwagen               2001  manuell        75   golf     150000
# 1   kleinwagen               2008  manuell        69  fabia      90000
#
#    Registration_month fuel_type       brand Unrepaired_damage Date_created  \
# 0                   6    benzin  volkswagen              nein   2016-03-17
# 1                   7    diesel       skoda              nein   2016-03-31
#
#    Postal_code            Last_seen
# 0        91074  2016-03-17 17:40:00
# 1        60437  2016-06-04 10:17:00

# %%
df.groupby(['brand'])['Price'].mean().sort_values(ascending = False)
# Out:
# brand
# porsche          54452.455842
# land_rover       19140.207237
# audi             19043.538144
# jaguar           15561.164882
# mercedes_benz    14022.670821
# jeep             13796.759322
# mini             10438.970557
# bmw               9485.176670
# chevrolet         7379.892687
# mazda             7376.347724
# skoda             7146.695266
# kia               6544.715217
# volkswagen        6398.572033
# hyundai           6155.322097
# dacia             6073.666667
# volvo             5961.606220
# ford              5898.658110
# toyota            5723.281109
# nissan            5559.090117
# seat              5248.758958
# subaru            5247.582375
# suzuki            5228.813008
# alfa_romeo        4811.786946
# chrysler          4660.930380
# honda             4618.426717
# saab              4375.626536
# citroen           4194.152430
# smart             4048.705533
# opel              4041.546582
# mitsubishi        3978.127188
# lancia            3864.572848
# ...

# %%
df.groupby(['Vehicle_type'])['Price'].mean().sort_values(ascending = False)
# Out:
# Vehicle_type
# coupe         21997.212377
# suv           14233.722107
# cabrio        11381.474817
# kombi          8792.372477
# limousine      8419.751414
# bus            7667.570895
# andere         4748.899867
# kleinwagen     3247.702590
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1)
b = df.groupby(['Vehicle_type'])['Price'].mean().sort_values(ascending = False)
b.plot(kind = 'bar')
plt.xticks(rotation = 0)
plt.xlabel('Vehicle Type',labelpad=0)

plt.subplot(2,1,2)
a =df.groupby(['brand'])['Price'].mean().sort_values(ascending = False)
a.plot(kind = 'bar')
plt.show()
